# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
epl = pd.read_csv("EPL_Set.csv")

# %%
epl
# Out:
#      Div      Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0     E0  14/08/93      Arsenal        Coventry     0     3   A   NaN   NaN
# 1     E0  14/08/93  Aston Villa             QPR     4     1   H   NaN   NaN
# 2     E0  14/08/93      Chelsea       Blackburn     1     2   A   NaN   NaN
# 3     E0  14/08/93    Liverpool  Sheffield Weds     2     0   H   NaN   NaN
# 4     E0  14/08/93     Man City           Leeds     1     1   D   NaN   NaN
# ...   ..       ...          ...             ...   ...   ...  ..   ...   ...
# 9659  E0  13/05/18    Newcastle         Chelsea     3     0   H   1.0   0.0
# 9660  E0  13/05/18  Southampton        Man City     0     1   A   0.0   0.0
# 9661  E0  13/05/18      Swansea           Stoke     1     2   A   1.0   2.0
# 9662  E0  13/05/18    Tottenham       Leicester     5     4   H   1.0   2.0
# 9663  E0  13/05/18     West Ham         Everton     3     1   H   1.0   0.0
#
#       HTR   Season
# 0     NaN  1993-94
# ...

# %%
epl.HomeTeam.unique()
# Out:
# array(['Arsenal', 'Aston Villa', 'Chelsea', 'Liverpool', 'Man City',
#        'Newcastle', 'Oldham', 'Sheffield United', 'Southampton',
#        'West Ham', 'Norwich', 'Tottenham', 'Everton', 'Ipswich', 'Leeds',
#        'Wimbledon', 'Blackburn', 'Coventry', 'Man United', 'QPR',
#        'Sheffield Weds', 'Swindon', 'Crystal Palace', 'Leicester',
#        "Nott'm Forest", 'Bolton', 'Middlesbrough', 'Derby', 'Sunderland',
#        'Barnsley', 'Charlton', 'Watford', 'Bradford', 'Fulham',
#        'Birmingham', 'Middlesboro', 'West Brom', 'Portsmouth', 'Wolves',
#        'Wigan', 'Reading', 'Hull', 'Stoke', 'Burnley', 'Blackpool',
#        'Swansea', 'Cardiff', 'Bournemouth', 'Brighton', 'Huddersfield'],
#       dtype=object)

# %%
epl.FTHG[epl["HomeTeam"] == "Chelsea"]
# Out:
# 2       1
# 38      2
# 47      1
# 68      1
# 90      1
#        ..
# 9574    2
# 9597    1
# 9607    1
# 9646    1
# 9649    1
# Name: FTHG, Length: 479, dtype: int64

# %%
epl.FTAG[epl["AwayTeam"] == "Chelsea"]
# Out:
# 15      1
# 25      0
# 65      1
# 78      1
# 107     0
#        ..
# 9572    0
# 9612    3
# 9620    2
# 9634    1
# 9659    0
# Name: FTAG, Length: 479, dtype: int64

# %%
H_Chelsea = epl.groupby("HomeTeam")

# %%
H_Chelsea

# %%
HomeChelsea = H_Chelsea.get_group("Chelsea")

# %%
HomeChelsea
# Out:
#      Div       Date HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR  \
# 2     E0   14/08/93  Chelsea       Blackburn     1     2   A   NaN   NaN  NaN
# 38    E0   25/08/93  Chelsea             QPR     2     0   H   NaN   NaN  NaN
# 47    E0   28/08/93  Chelsea  Sheffield Weds     1     1   D   NaN   NaN  NaN
# 68    E0  11/9/1993  Chelsea      Man United     1     0   H   NaN   NaN  NaN
# 90    E0   25/09/93  Chelsea       Liverpool     1     0   H   NaN   NaN  NaN
# ...   ..        ...      ...             ...   ...   ...  ..   ...   ...  ...
# 9574  E0  10/3/2018  Chelsea  Crystal Palace     2     1   H   2.0   0.0    H
# 9597  E0   1/4/2018  Chelsea       Tottenham     1     3   A   1.0   1.0    D
# 9607  E0   8/4/2018  Chelsea        West Ham     1     1   D   1.0   0.0    H
# 9646  E0   6/5/2018  Chelsea       Liverpool     1     0   H   1.0   0.0    H
# 9649  E0   9/5/2018  Chelsea    Huddersfield     1     1   D   0.0   0.0    D
#
#        Season
# 2     1993-94
# ...

# %%
A_Chelsea = epl.groupby("AwayTeam")

# %%
AwayChelsea = A_Chelsea.get_group("Chelsea")

# %%
AwayChelsea
# Out:
#      Div       Date     HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR  \
# 15    E0   17/08/93    Wimbledon  Chelsea     1     1   D   NaN   NaN  NaN
# 25    E0   21/08/93      Ipswich  Chelsea     1     0   H   NaN   NaN  NaN
# 65    E0   1/9/1993    Tottenham  Chelsea     1     1   D   NaN   NaN  NaN
# 78    E0   18/09/93     Coventry  Chelsea     1     1   D   NaN   NaN  NaN
# 107   E0  2/10/1993     West Ham  Chelsea     1     0   H   NaN   NaN  NaN
# ...   ..        ...          ...      ...   ...   ...  ..   ...   ...  ...
# 9572  E0   4/3/2018     Man City  Chelsea     1     0   H   0.0   0.0    D
# 9612  E0   14/04/18  Southampton  Chelsea     2     3   A   1.0   0.0    H
# 9620  E0   19/04/18      Burnley  Chelsea     1     2   A   0.0   1.0    A
# 9634  E0   28/04/18      Swansea  Chelsea     0     1   A   0.0   1.0    A
# 9659  E0   13/05/18    Newcastle  Chelsea     3     0   H   1.0   0.0    H
#
#        Season
# 15    1993-94
# 25    1993-94
# 65    1993-94
# ...

# %%
# date_format = "%m/%d/%Y"
AwayChelsea["Date"] = pd.to_datetime(AwayChelsea["Date"])
# Out:
# C:\Users\MUHAMM~1\AppData\Local\Temp/ipykernel_6584/4018025646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AwayChelsea["Date"] = pd.to_datetime(AwayChelsea["Date"])

# %%
AwayChelsea
# Out:
#      Div       Date     HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR  \
# 15    E0 1993-08-17    Wimbledon  Chelsea     1     1   D   NaN   NaN  NaN
# 25    E0 1993-08-21      Ipswich  Chelsea     1     0   H   NaN   NaN  NaN
# 65    E0 1993-01-09    Tottenham  Chelsea     1     1   D   NaN   NaN  NaN
# 78    E0 1993-09-18     Coventry  Chelsea     1     1   D   NaN   NaN  NaN
# 107   E0 1993-02-10     West Ham  Chelsea     1     0   H   NaN   NaN  NaN
# ...   ..        ...          ...      ...   ...   ...  ..   ...   ...  ...
# 9572  E0 2018-04-03     Man City  Chelsea     1     0   H   0.0   0.0    D
# 9612  E0 2018-04-14  Southampton  Chelsea     2     3   A   1.0   0.0    H
# 9620  E0 2018-04-19      Burnley  Chelsea     1     2   A   0.0   1.0    A
# 9634  E0 2018-04-28      Swansea  Chelsea     0     1   A   0.0   1.0    A
# 9659  E0 2018-05-13    Newcastle  Chelsea     3     0   H   1.0   0.0    H
#
#        Season
# 15    1993-94
# 25    1993-94
# 65    1993-94
# ...

# %%
HomeChelsea["Date"] = pd.to_datetime(HomeChelsea["Date"])
# Out:
# C:\Users\MUHAMM~1\AppData\Local\Temp/ipykernel_6584/778006771.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HomeChelsea["Date"] = pd.to_datetime(HomeChelsea["Date"])

# %%
HomeChelsea
# Out:
#      Div       Date HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR  \
# 2     E0 1993-08-14  Chelsea       Blackburn     1     2   A   NaN   NaN  NaN
# 38    E0 1993-08-25  Chelsea             QPR     2     0   H   NaN   NaN  NaN
# 47    E0 1993-08-28  Chelsea  Sheffield Weds     1     1   D   NaN   NaN  NaN
# 68    E0 1993-11-09  Chelsea      Man United     1     0   H   NaN   NaN  NaN
# 90    E0 1993-09-25  Chelsea       Liverpool     1     0   H   NaN   NaN  NaN
# ...   ..        ...      ...             ...   ...   ...  ..   ...   ...  ...
# 9574  E0 2018-10-03  Chelsea  Crystal Palace     2     1   H   2.0   0.0    H
# 9597  E0 2018-01-04  Chelsea       Tottenham     1     3   A   1.0   1.0    D
# 9607  E0 2018-08-04  Chelsea        West Ham     1     1   D   1.0   0.0    H
# 9646  E0 2018-06-05  Chelsea       Liverpool     1     0   H   1.0   0.0    H
# 9649  E0 2018-09-05  Chelsea    Huddersfield     1     1   D   0.0   0.0    D
#
#        Season
# 2     1993-94
# ...

# %%
epl = epl[(epl.HomeTeam=="Chelsea") | (epl.AwayTeam == "Chelsea")]

# %%
epl["Date"] = pd.to_datetime(epl["Date"])
# Out:
# C:\Users\MUHAMM~1\AppData\Local\Temp/ipykernel_6584/754847836.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   epl["Date"] = pd.to_datetime(epl["Date"])

# %%
epl = epl[epl.Season.str.startswith("200")]

# %%
awayWins = epl[(epl.HomeTeam == "Chelsea") & (epl.FTR =="H") ]

# %%
homeWins = epl[(epl.AwayTeam == "Chelsea") & (epl.FTR =="A") ]

# %%
draws = epl[(epl.FTR =="D")]

# %%
wins = pd.concat([awayWins,homeWins])

# %%
wins
# Out:
#      Div       Date    HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 2825  E0 2000-08-19     Chelsea   West Ham     4     2   H   1.0   0.0   H
# 2901  E0 2000-01-10     Chelsea  Liverpool     3     0   H   2.0   0.0   H
# 2915  E0 2000-10-21     Chelsea   Coventry     6     1   H   2.0   0.0   H
# 2925  E0 2000-10-28     Chelsea  Tottenham     3     0   H   2.0   0.0   H
# 2981  E0 2000-03-12     Chelsea   Man City     2     1   H   2.0   0.0   H
# ...   ..        ...         ...        ...   ...   ...  ..   ...   ...  ..
# 6465  E0 2010-01-30     Burnley    Chelsea     1     2   A   0.0   1.0   A
# 6502  E0 2010-02-20      Wolves    Chelsea     0     2   A   0.0   1.0   A
# 6550  E0 2010-03-24  Portsmouth    Chelsea     0     5   A   0.0   1.0   A
# 6564  E0 2010-03-04  Man United    Chelsea     1     2   A   0.0   1.0   A
# 6608  E0 2010-02-05   Liverpool    Chelsea     0     2   A   0.0   1.0   A
#
#        Season
# 2825  2000-01
# 2901  2000-01
# 2915  2000-01
# ...

# %%
import seaborn as sns

# %%
draws
# Out:
#      Div       Date     HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 2852  E0 2000-08-27  Aston Villa  Chelsea     1     1   D   1.0   1.0   D
# 2858  E0 2000-06-09      Chelsea  Arsenal     2     2   D   1.0   0.0   H
# 2870  E0 2000-09-09    Newcastle  Chelsea     0     0   D   0.0   0.0   D
# 2888  E0 2000-09-23   Man United  Chelsea     3     3   D   3.0   2.0   H
# 2951  E0 2000-12-11      Chelsea    Leeds     1     1   D   0.0   0.0   D
# ...   ..        ...          ...      ...   ...   ...  ..   ...   ...  ..
# 6396  E0 2009-12-12      Chelsea  Everton     3     3   D   2.0   2.0   D
# 6418  E0 2009-12-20     West Ham  Chelsea     1     1   D   1.0   0.0   H
# 6420  E0 2009-12-26   Birmingham  Chelsea     0     0   D   0.0   0.0   D
# 6474  E0 2010-02-02         Hull  Chelsea     1     1   D   1.0   1.0   D
# 6543  E0 2010-03-21    Blackburn  Chelsea     1     1   D   0.0   1.0   A
#
#        Season
# 2852  2000-01
# 2858  2000-01
# 2870  2000-01
# 2888  2000-01
# ...

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='Season', data=draws, hue )
sns.countplot(x='Season',data=wins)
plt.show()
