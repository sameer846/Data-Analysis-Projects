# %% [markdown]
# # laptops data

# %%
import pandas as pd

# %%
#laptop=pd.read_csv("laptops.csv")

# %%
f500=pd.read_csv("f500.csv")

# %% [markdown]
# # Logical Operators
# * & and operator
# * | or operator
# * ~ not operator

# %%
f500[(f500.country=="USA") & (f500.sector=="Technology")]
# Out:
#                         company  rank  revenues  revenue_change  profits  \
# 8                         Apple     9    215639            -7.7  45687.0
# 25                   Amazon.com    26    135987            27.1   2371.0
# 64                     Alphabet    65     90272            20.4  19478.0
# 68                    Microsoft    69     85320            -8.8  16798.0
# 80                          IBM    81     79919            -3.1  11872.0
# 123           Dell Technologies   124     64806            18.1  -1672.0
# 143                       Intel   144     59387             7.3  10316.0
# 180  Hewlett Packard Enterprise   181     50123             NaN   3161.0
# 186               Cisco Systems   187     49247             0.2  10739.0
# 193                          HP   194     48238           -53.3   2496.0
# 259     Honeywell International   260     39302             1.9   4809.0
# 279                      Oracle   280     37047            -3.1   8901.0
# ...

# %%
f500[(f500.country=="USA") & (f500.sector=="Technology")].head()
# Out:
#        company  rank  revenues  revenue_change  profits  assets  \
# 8        Apple     9    215639            -7.7  45687.0  321686
# 25  Amazon.com    26    135987            27.1   2371.0   83402
# 64    Alphabet    65     90272            20.4  19478.0  167497
# 68   Microsoft    69     85320            -8.8  16798.0  193694
# 80         IBM    81     79919            -3.1  11872.0  117470
#
#     profit_change                  ceo                         industry  \
# 8           -14.4      Timothy D. Cook      Computers, Office Equipment
# 25          297.8     Jeffrey P. Bezos  Internet Services and Retailing
# 64           19.1           Larry Page  Internet Services and Retailing
# 68           37.8        Satya Nadella                Computer Software
# 80          -10.0  Virginia M. Rometty  Information Technology Services
#
#         sector  previous_rank country        hq_location  \
# 8   Technology              9     USA      Cupertino, CA
# ...

# %%
f500[(f500.country=="USA") &  ~(f500.sector=="Technology")]
# Out:
#                 company  rank  revenues  revenue_change  profits  assets  \
# 0               Walmart     1    485873             0.8  13643.0  198825
# 7    Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 9           Exxon Mobil    10    205004           -16.7   7840.0  330314
# 10             McKesson    11    198533             3.1   5070.0   60969
# 12   UnitedHealth Group    13    184840            17.7   7017.0  122810
# ..                  ...   ...       ...             ...      ...     ...
# 480        U.S. Bancorp   481     22744             5.8   5888.0  445964
# 482               Aflac   483     22559             8.1   2659.0  129819
# 488      Sears Holdings   489     22138           -12.0  -2221.0    9362
# 491      Dollar General   492     21987             7.9   1251.1   11672
# 499          AutoNation   500     21609             3.6    430.5   10060
#
#      profit_change                  ceo  \
# 0             -7.2  C. Douglas McMillon
# ...

# %%
countries=f500.country.unique()

# %%
countries
# Out:
# array(['USA', 'China', 'Japan', 'Germany', 'Netherlands', 'Britain',
#        'South Korea', 'Switzerland', 'France', 'Taiwan', 'Singapore',
#        'Italy', 'Russia', 'Spain', 'Brazil', 'Mexico', 'Luxembourg',
#        'India', 'Malaysia', 'Thailand', 'Australia', 'Belgium', 'Norway',
#        'Canada', 'Ireland', 'Indonesia', 'Denmark', 'Saudi Arabia',
#        'Sweden', 'Finland', 'Venezuela', 'Turkey', 'U.A.E', 'Israel'],
#       dtype=object)

# %%
top_employ={}
for i in countries:
    df=f500[f500.country==i]
    df_sort_employees=df.sort_values("employees",ascending= False)
    top_employ[i]=df_sort_employees.iloc[0,0]

# %%
top_employ
# Out:
# {'USA': 'Walmart',
#  'China': 'China National Petroleum',
#  'Japan': 'Toyota Motor',
#  'Germany': 'Volkswagen',
#  'Netherlands': 'EXOR Group',
#  'Britain': 'Compass Group',
#  'South Korea': 'Samsung Electronics',
#  'Switzerland': 'Nestle',
#  'France': 'Sodexo',
#  'Taiwan': 'Hon Hai Precision Industry',
#  'Singapore': 'Flex',
#  'Italy': 'Poste Italiane',
#  'Russia': 'Gazprom',
#  'Spain': 'Banco Santander',
#  'Brazil': 'JBS',
#  'Mexico': 'America Movil',
#  'Luxembourg': 'ArcelorMittal',
#  'India': 'State Bank of India',
#  'Malaysia': 'Petronas',
#  'Thailand': 'PTT',
#  'Australia': 'Wesfarmers',
#  'Belgium': 'Anheuser-Busch InBev',
#  'Norway': 'Statoil',
#  'Canada': 'George Weston',
#  'Ireland': 'Accenture',
#  'Indonesia': 'Pertamina',
#  'Denmark': 'Maersk Group',
#  'Saudi Arabia': 'SABIC',
#  'Sweden': 'H & M Hennes & Mauritz',
#  'Finland': 'Nokia',
#  'Venezuela': 'Mercantil Servicios Financieros',
#  'Turkey': 'Koc Holding',
#  'U.A.E': 'Emirates Group',
# ...

# %%
top_employ= pd.Series()
for i in countries:
    df=f500[f500.country==i]
    df_sort_employees=df.sort_values("employees",ascending= False)
    top_employ[i]=df_sort_employees.iloc[0,0]
top_employ
# Out:
# C:\Users\samkh\AppData\Local\Temp\ipykernel_10552\2828209441.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   top_employ= pd.Series()
# USA                                     Walmart
# China                  China National Petroleum
# Japan                              Toyota Motor
# Germany                              Volkswagen
# Netherlands                          EXOR Group
# Britain                           Compass Group
# South Korea                 Samsung Electronics
# Switzerland                              Nestle
# France                                   Sodexo
# Taiwan               Hon Hai Precision Industry
# Singapore                                  Flex
# Italy                            Poste Italiane
# Russia                                  Gazprom
# Spain                           Banco Santander
# ...

# %%
german_df=f500[f500.country=="Germany"]

# %%
german_sort_employees=german_df.sort_values("employees",ascending=False)

# %%
german_sort_employees.iloc[0,0]
# Out:
# 'Volkswagen'

# %%
german_sort_employees.to_excel("germandata.xlsx",index=False)

# %%
laptops=pd.read_csv("laptops.csv",encoding="latin-1")

# %%
laptops.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
laptops.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price (Euros)'],
#       dtype='object')

# %%
_G
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 _G
#
# NameError: name '_G' is not defined

# %%
laptops.columns.str.strip().str.replace("(","").str.replace(")","")
# Out:
# C:\Users\samkh\AppData\Local\Temp\ipykernel_10552\449606845.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   laptops.columns.str.strip().str.replace("(","").str.replace(")","")
# C:\Users\samkh\AppData\Local\Temp\ipykernel_10552\449606845.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   laptops.columns.str.strip().str.replace("(","").str.replace(")","")
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', 'Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price Euros'],
#       dtype='object')

# %%
laptops.columns.str.strip().str.replace("(","").str.replace(")","").str.replace(" ","_")
# Out:
# C:\Users\samkh\AppData\Local\Temp\ipykernel_10552\3271802113.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   laptops.columns.str.strip().str.replace("(","").str.replace(")","").str.replace(" ","_")
# C:\Users\samkh\AppData\Local\Temp\ipykernel_10552\3271802113.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   laptops.columns.str.strip().str.replace("(","").str.replace(")","").str.replace(" ","_")
# Index(['Manufacturer', 'Model_Name', 'Category', 'Screen_Size', 'Screen',
#        'CPU', 'RAM', 'Storage', 'GPU', 'Operating_System',
#        'Operating_System_Version', 'Weight', 'Price_Euros'],
#       dtype='object')

# %%
laptops.columns.str.strip().str.replace("(","").str.replace(")","").str.replace(" ","_").str.lower()
# Out:
# C:\Users\samkh\AppData\Local\Temp\ipykernel_10552\921200485.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   laptops.columns.str.strip().str.replace("(","").str.replace(")","").str.replace(" ","_").str.lower()
# C:\Users\samkh\AppData\Local\Temp\ipykernel_10552\921200485.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   laptops.columns.str.strip().str.replace("(","").str.replace(")","").str.replace(" ","_").str.lower()
# Index(['manufacturer', 'model_name', 'category', 'screen_size', 'screen',
#        'cpu', 'ram', 'storage', 'gpu', 'operating_system',
#        'operating_system_version', 'weight', 'price_euros'],
#       dtype='object')

# %%
laptops.columns=laptops.columns.str.strip().str.replace("(","").str.replace(")","").str.replace(" ","_").str.lower().str.replace("operating_system","os")
# Out:
# C:\Users\samkh\AppData\Local\Temp\ipykernel_10552\28027980.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   laptops.columns=laptops.columns.str.strip().str.replace("(","").str.replace(")","").str.replace(" ","_").str.lower().str.replace("operating_system","os")
# C:\Users\samkh\AppData\Local\Temp\ipykernel_10552\28027980.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   laptops.columns=laptops.columns.str.strip().str.replace("(","").str.replace(")","").str.replace(" ","_").str.lower().str.replace("operating_system","os")

# %%
laptops.columns
# Out:
# Index(['manufacturer', 'model_name', 'category', 'screen_size', 'screen',
#        'cpu', 'ram', 'storage', 'gpu', 'os', 'os_version', 'weight',
#        'price_euros'],
#       dtype='object')

# %%
laptops.screen_size
# Out:
# 0       13.3"
# 1       13.3"
# 2       15.6"
# 3       15.4"
# 4       13.3"
#         ...
# 1298    14.0"
# 1299    13.3"
# 1300    14.0"
# 1301    15.6"
# 1302    15.6"
# Name: screen_size, Length: 1303, dtype: object

# %%
laptops.screen_size.str.strip('"')
# Out:
# 0       13.3
# 1       13.3
# 2       15.6
# 3       15.4
# 4       13.3
#         ...
# 1298    14.0
# 1299    13.3
# 1300    14.0
# 1301    15.6
# 1302    15.6
# Name: screen_size, Length: 1303, dtype: object

# %%
laptops.screen_size=laptops.screen_size.str.strip('"').astype(float)

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  1303 non-null   object
#  1   model_name    1303 non-null   object
#  2   category      1303 non-null   object
#  3   screen_size   1303 non-null   float64
#  4   screen        1303 non-null   object
#  5   cpu           1303 non-null   object
#  6   ram           1303 non-null   object
#  7   storage       1303 non-null   object
#  8   gpu           1303 non-null   object
#  9   os            1303 non-null   object
#  10  os_version    1133 non-null   object
#  11  weight        1303 non-null   object
#  12  price_euros   1303 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 132.5+ KB

# %%
laptops.ram
# Out:
# 0        8GB
# 1        8GB
# 2        8GB
# 3       16GB
# 4        8GB
#         ...
# 1298     4GB
# 1299    16GB
# 1300     2GB
# 1301     6GB
# 1302     4GB
# Name: ram, Length: 1303, dtype: object

# %%
laptops.ram.str.strip("GB").astype(int)
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1298     4
# 1299    16
# 1300     2
# 1301     6
# 1302     4
# Name: ram, Length: 1303, dtype: int32

# %%
laptops.ram=laptops.ram.str.strip("GB").astype(int)

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  1303 non-null   object
#  1   model_name    1303 non-null   object
#  2   category      1303 non-null   object
#  3   screen_size   1303 non-null   float64
#  4   screen        1303 non-null   object
#  5   cpu           1303 non-null   object
#  6   ram           1303 non-null   int32
#  7   storage       1303 non-null   object
#  8   gpu           1303 non-null   object
#  9   os            1303 non-null   object
#  10  os_version    1133 non-null   object
#  11  weight        1303 non-null   object
#  12  price_euros   1303 non-null   object
# dtypes: float64(1), int32(1), object(11)
# memory usage: 127.4+ KB

# %%
laptops.rename({"ram":"ram_in_GB"},axis=1,inplace=True)

# %%
laptops.head()
# Out:
#   manufacturer   model_name   category  screen_size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                screen                         cpu  ram_in_GB  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz          8
# 1                            1440x900        Intel Core i5 1.8GHz          8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz          8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz         16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz          8
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# ...

# %%
laptops["os_version"].value_counts(dropna=False)
# Out:
# 10      1072
# NaN      170
# 7         45
# X          8
# 10 S       8
# Name: os_version, dtype: int64
