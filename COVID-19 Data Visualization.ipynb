# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
who_time_series = pd.read_csv("WHO.csv")
who_time_series.head()
# Out:
#   Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 0    2020-01-04   China          1                 1           0
# 1    2020-01-05   China          0                 1           0
# 2    2020-01-06   China          3                 4           0
# 3    2020-01-07   China          0                 4           0
# 4    2020-01-08   China          0                 4           0
#
#    Cumulative_deaths
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
who_time_series.dtypes
# Out:
# Date_reported        object
# Country              object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
who_time_series["Date_reported"] = pd.to_datetime(who_time_series["Date_reported"])

# %%
who_time_series.dtypes
# Out:
# Date_reported        datetime64[ns]
# Country                      object
# New_cases                     int64
# Cumulative_cases              int64
# New_deaths                    int64
# Cumulative_deaths             int64
# dtype: object

# %%
italy = who_time_series[who_time_series["Country"] == "Italy"]

# %%
italy
# Out:
#       Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 123      2020-01-29   Italy          6                 6           0
# 144      2020-01-30   Italy          0                 6           0
# 158      2020-01-31   Italy          0                 6           0
# 187      2020-02-01   Italy          0                 6           0
# 215      2020-02-02   Italy          0                 6           0
# ...             ...     ...        ...               ...         ...
# 30870    2020-07-27   Italy        254            246118           5
# 31097    2020-07-28   Italy        168            246286           5
# 31333    2020-07-29   Italy        202            246488          11
# 31629    2020-07-30   Italy        288            246776           6
# 31686    2020-07-31   Italy        382            247158           3
#
#        Cumulative_deaths
# 123                    0
# 144                    0
# 158                    0
# 187                    0
# 215                    0
# ...                  ...
# 30870              35107
# 31097              35112
# 31333              35123
# 31629              35129
# 31686              35132
#
# [185 rows x 6 columns]

# %%
plt.plot(italy["Date_reported"], italy["Cumulative_cases"])

plt.show()

# %%
plt.plot(italy["Date_reported"], italy["Cumulative_cases"])
plt.title("Italy : Cumulative Reported Cases")
plt.xlabel("Date")
plt.ylabel("Number of Cases")
plt.show()

print("Generally, a quantity that increase very quickly in the begining and the it slows down more and more over time has a LOGARITHMIC GROWTH")
# Out:
# Generally, a quantity that increase very quickly in the begining and the it slows down more and more over time has a LOGARITHMIC GROWTH

# %%
india = who_time_series[who_time_series["Country"] == "India"]

# %%
plt.plot(india["Date_reported"], india["Cumulative_cases"])
plt.title("India : Cumulative Reported Cases")
plt.xlabel("Date")
plt.ylabel("Number of Cases")
plt.show()

# %%
1.50 * 10**6
# Out:
# 1500000.0

# %%
plt.plot(india["Date_reported"], india["Cumulative_cases"])
plt.title("India : Cumulative Reported Cases")
plt.xlabel("Date")
plt.ylabel("Number of Cases")
plt.ticklabel_format(axis = "y", style = "plain")
plt.show()

print("India shows exponential growth for the data we have, but when the number of new cases will decrease, the growth will become logarithmic.")
# Out:
# India shows exponential growth for the data we have, but when the number of new cases will decrease, the growth will become logarithmic.

# %%
"There are {} cases in {}".format(2334,"Pakistan")
# Out:
# 'There are 2334 cases in Pakistan'

# %%
"There are {:,} cases in {}".format(2323334,"Pakistan")
# Out:
# 'There are 2,323,334 cases in Pakistan'

# %%
def plot_cases(country_name):
    df = who_time_series[who_time_series["Country"] == country_name]
    plt.plot(df["Date_reported"], df["Cumulative_cases"])
    plt.title("{} : CovidReported Cases".format(country_name))
    plt.xlabel("Date")
    plt.ylabel("Number of Cases")
    plt.ticklabel_format(axis = "y", style = "plain")
    plt.show()

# %%
plot_cases("Poland")

print("Generally, a quantity that increase constantly over time has linear growth.")
# Out:
# Generally, a quantity that increase constantly over time has linear growth.

# %%
countries = who_time_series["Country"].unique()
countries[:10]
# Out:
# array(['China', 'Thailand', 'Japan', 'Republic of Korea',
#        'United States of America', 'Singapore', 'Nepal', 'France',
#        'Viet Nam', 'Malaysia'], dtype=object)

# %%
for i in countries[:10]:
    plot_cases(i)

# %%
france = who_time_series[who_time_series["Country"] == "France"]
uk = who_time_series[who_time_series["Country"] == "The United Kingdom"]
pakistan = who_time_series[who_time_series["Country"] == "Pakistan"]

# %%
plt.plot(france["Date_reported"], france["Cumulative_cases"])
plt.plot(uk["Date_reported"], uk["Cumulative_cases"])
plt.show()

plt.plot(pakistan["Date_reported"], pakistan["Cumulative_cases"])
plt.show()

# %%
plt.plot(france["Date_reported"], france["Cumulative_cases"], label = "France", color = "Blue")
plt.plot(uk["Date_reported"], uk["Cumulative_cases"], label = "UK", color = "red")
plt.plot(pakistan["Date_reported"], pakistan["Cumulative_cases"], label = "Pakistan", color = "green")
plt.legend()
plt.show()

# %% [markdown]
# # Scatter Plots and Correlations

# %%
bike_sharing = pd.read_csv("day.csv")

# %%
bike_sharing.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
bike_sharing["dteday"] = pd.to_datetime(bike_sharing["dteday"])

# %%
bike_sharing["dteday"]
# Out:
# 0     2011-01-01
# 1     2011-01-02
# 2     2011-01-03
# 3     2011-01-04
# 4     2011-01-05
#          ...
# 726   2012-12-27
# 727   2012-12-28
# 728   2012-12-29
# 729   2012-12-30
# 730   2012-12-31
# Name: dteday, Length: 731, dtype: datetime64[ns]

# %%
# plt.figure(figsize=(10,4))
plt.plot(bike_sharing["dteday"], bike_sharing["cnt"])
plt.xticks(rotation = 90)

plt.show()

# %%
# plt.figure(figsize=(10,4))
plt.plot(bike_sharing["dteday"], bike_sharing["temp"])
plt.xticks(rotation = 90)

plt.show()

# %%
plt.plot(bike_sharing["dteday"], bike_sharing["windspeed"])
plt.xticks(rotation = 90)

plt.show()

# %%
bike_sharing.temp.corr(bike_sharing.cnt)
# Out:
# 0.6274940090334918

# %%
bike_sharing.temp.corr(bike_sharing.cnt)*100
# Out:
# 62.74940090334918

# %%
plt.scatter(bike_sharing["temp"], bike_sharing["cnt"])
plt.xlabel("Temp")
plt.ylabel("Bikes Rented")

plt.show()
