# %%
import pandas as pd

# %%
import sqlite3 as sql

# %%
database ="jobs.db"
conn=sql.connect(database)

# %%
conn

# %%
pd.read_sql_query("select * from sqlite_master",conn)
# Out:
#     type                   name      tbl_name  rootpage  \
# 0  table           recent_grads  recent_grads         2
# 1  index  ix_recent_grads_index  recent_grads         3
#
#                                                  sql
# 0  CREATE TABLE "recent_grads" (\n"index" INTEGER...
# 1  CREATE INDEX "ix_recent_grads_index"ON "recent...

# %%
q="""select Sharewomen,Major,Major_category from recent_grads 
where Sharewomen>0.5 OR (Sharewomen<0.5 and Major="Engineering")
ORDER BY 1 DESC"""
pd.read_sql_query(q,conn)
# Out:
#     ShareWomen                                    Major  \
# 0     0.968954              ANTHROPOLOGY AND ARCHEOLOGY
# 1     0.967998                EARLY CHILDHOOD EDUCATION
# 2     0.927807         MATHEMATICS AND COMPUTER SCIENCE
# 3     0.923745                     ELEMENTARY EDUCATION
# 4     0.910933                          ANIMAL SCIENCES
# ..         ...                                      ...
# 92    0.515406                     BIOCHEMICAL SCIENCES
# 93    0.507377  INTERCULTURAL AND INTERNATIONAL STUDIES
# 94    0.506721   PHYSICAL AND HEALTH EDUCATION TEACHING
# 95    0.505141                                CHEMISTRY
# 96    0.502846                  GENERAL SOCIAL SCIENCES
#
#                      Major_category
# 0         Humanities & Liberal Arts
# 1                         Education
# 2           Computers & Mathematics
# 3                         Education
# 4   Agriculture & Natural Resources
# ..                              ...
# ...

# %%
q="""select Sharewomen,Major,Major_category from recent_grads 
where Sharewomen>0.5 OR (Sharewomen<0.5 and Major_category="Engineering")
ORDER BY 1 DESC"""
pd.read_sql_query(q,conn)
# Out:
#      ShareWomen                                      Major  \
# 0      0.968954                ANTHROPOLOGY AND ARCHEOLOGY
# 1      0.967998                  EARLY CHILDHOOD EDUCATION
# 2      0.927807           MATHEMATICS AND COMPUTER SCIENCE
# 3      0.923745                       ELEMENTARY EDUCATION
# 4      0.910933                            ANIMAL SCIENCES
# ..          ...                                        ...
# 119    0.119559                     BIOMEDICAL ENGINEERING
# 120    0.107313  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 121    0.101852             MINING AND MINERAL ENGINEERING
# 122    0.090713                   ENGINEERING TECHNOLOGIES
# 123    0.000000     MISCELLANEOUS ENGINEERING TECHNOLOGIES
#
#                       Major_category
# 0          Humanities & Liberal Arts
# 1                          Education
# 2            Computers & Mathematics
# 3                          Education
# 4    Agriculture & Natural Resources
# ...

# %%
q="""select Major_category, avg(ShareWomen) as avg_share from recent_grads
where ShareWomen>0.4
group by 1
having ShareWomen>.6"""
pd.read_sql_query(q,conn)
# Out:
#                 Major_category  avg_share
# 0  Communications & Journalism   0.756743
# 1                       Health   0.656663
# 2    Humanities & Liberal Arts   0.700231
# 3               Social Science   0.563848

# %%
q="""select distinct(Major_category) from recent_grads"""
pd.read_sql_query(q,conn)
# Out:
#                          Major_category
# 0                           Engineering
# 1                              Business
# 2                     Physical Sciences
# 3                   Law & Public Policy
# 4               Computers & Mathematics
# 5       Agriculture & Natural Resources
# 6   Industrial Arts & Consumer Services
# 7                                  Arts
# 8                                Health
# 9                        Social Science
# 10               Biology & Life Science
# 11                            Education
# 12            Humanities & Liberal Arts
# 13             Psychology & Social Work
# 14          Communications & Journalism
# 15                    Interdisciplinary

# %%
q="""select Major_category, avg(ShareWomen) as avg_share from recent_grads
where ShareWomen>0.4
group by Major_category
having avg_share>.6"""
pd.read_sql_query(q,conn)
# Out:
#                         Major_category  avg_share
# 0      Agriculture & Natural Resources   0.661854
# 1               Biology & Life Science   0.623524
# 2          Communications & Journalism   0.756743
# 3              Computers & Mathematics   0.726525
# 4                            Education   0.695573
# 5                               Health   0.656663
# 6            Humanities & Liberal Arts   0.700231
# 7  Industrial Arts & Consumer Services   0.621924
# 8             Psychology & Social Work   0.777763

# %%
q="""select Women,Men,Total from recent_grads"""
pd.read_sql_query(q,conn)
# Out:
#      Women    Men  Total
# 0      282   2057   2339
# 1       77    679    756
# 2      131    725    856
# 3      135   1123   1258
# 4    11021  21239  32260
# ..     ...    ...    ...
# 168   5359   3050   8409
# 169   2332    522   2854
# 170   2270    568   2838
# 171   3695    931   4626
# 172    964    134   1098
#
# [173 rows x 3 columns]

# %%
q="""select Major,Major_category,Women,Men,Sharewomen from recent_grads 
where Women>Men"""
pd.read_sql_query(q,conn)
# Out:
#                                  Major            Major_category   Women  \
# 0                    ACTUARIAL SCIENCE                  Business     960
# 1                     COMPUTER SCIENCE   Computers & Mathematics    2524
# 2            ENVIRONMENTAL ENGINEERING               Engineering    3339
# 3                              NURSING                    Health  187621
# 4   INDUSTRIAL PRODUCTION TECHNOLOGIES               Engineering    1588
# ..                                 ...                       ...     ...
# 92                             ZOOLOGY    Biology & Life Science    5359
# 93              EDUCATIONAL PSYCHOLOGY  Psychology & Social Work    2332
# 94                 CLINICAL PSYCHOLOGY  Psychology & Social Work    2270
# 95               COUNSELING PSYCHOLOGY  Psychology & Social Work    3695
# 96                     LIBRARY SCIENCE                 Education     964
#
#       Men  ShareWomen
# 0     832    0.535714
# 1    1837    0.578766
# ...

# %%
q="""select Major_category,major,Unemployment_rate from recent_grads
where Major_category=='Engineering' OR Major_category=='Physical Sciences'"""
pd.read_sql_query(q,conn)
# Out:
#        Major_category                                              Major  \
# 0         Engineering                              PETROLEUM ENGINEERING
# 1         Engineering                     MINING AND MINERAL ENGINEERING
# 2         Engineering                          METALLURGICAL ENGINEERING
# 3         Engineering          NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4         Engineering                               CHEMICAL ENGINEERING
# 5         Engineering                                NUCLEAR ENGINEERING
# 6   Physical Sciences                         ASTRONOMY AND ASTROPHYSICS
# 7         Engineering                             MECHANICAL ENGINEERING
# 8         Engineering                             ELECTRICAL ENGINEERING
# 9         Engineering                               COMPUTER ENGINEERING
# 10        Engineering                              AEROSPACE ENGINEERING
# 11        Engineering                             BIOMEDICAL ENGINEERING
# ...

# %%
q="""select Major_category,major,Unemployment_rate from recent_grads
where Major_category in ('Engineering','Physical Sciences')"""
pd.read_sql_query(q,conn)
# Out:
#        Major_category                                              Major  \
# 0         Engineering                              PETROLEUM ENGINEERING
# 1         Engineering                     MINING AND MINERAL ENGINEERING
# 2         Engineering                          METALLURGICAL ENGINEERING
# 3         Engineering          NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4         Engineering                               CHEMICAL ENGINEERING
# 5         Engineering                                NUCLEAR ENGINEERING
# 6   Physical Sciences                         ASTRONOMY AND ASTROPHYSICS
# 7         Engineering                             MECHANICAL ENGINEERING
# 8         Engineering                             ELECTRICAL ENGINEERING
# 9         Engineering                               COMPUTER ENGINEERING
# 10        Engineering                              AEROSPACE ENGINEERING
# 11        Engineering                             BIOMEDICAL ENGINEERING
# ...

# %%
q="""select Major_category,major,Unemployment_rate from recent_grads
where Major_category in ('Engineering','Physical Sciences')
order by Sharewomen
limit 10"""
pd.read_sql_query(q,conn)
# Out:
#       Major_category                                      Major  \
# 0        Engineering     MISCELLANEOUS ENGINEERING TECHNOLOGIES
# 1        Engineering                   ENGINEERING TECHNOLOGIES
# 2        Engineering             MINING AND MINERAL ENGINEERING
# 3        Engineering  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        Engineering                     BIOMEDICAL ENGINEERING
# 5        Engineering                      PETROLEUM ENGINEERING
# 6  Physical Sciences       ATMOSPHERIC SCIENCES AND METEOROLOGY
# 7        Engineering                     MECHANICAL ENGINEERING
# 8        Engineering                        NUCLEAR ENGINEERING
# 9        Engineering                  METALLURGICAL ENGINEERING
#
#    Unemployment_rate
# 0           0.052539
# 1           0.055030
# 2           0.117241
# 3           0.050125
# 4           0.092084
# 5           0.018381
# 6           0.022229
# 7           0.057342
# 8           0.177226
# 9           0.024096

# %%
q="""select Major_category,major,Unemployment_rate from recent_grads
where Major_category in ('Engineering','Physical Sciences')
and Sharewomen between 0.5 and 0.8
order by Sharewomen
limit 10"""
pd.read_sql_query(q,conn)
# Out:
#       Major_category                                  Major  Unemployment_rate
# 0  Physical Sciences                              CHEMISTRY           0.053972
# 1        Engineering              ENVIRONMENTAL ENGINEERING           0.093589
# 2  Physical Sciences  MULTI-DISCIPLINARY OR GENERAL SCIENCE           0.055807
# 3  Physical Sciences                           OCEANOGRAPHY           0.056995
# 4        Engineering     INDUSTRIAL PRODUCTION TECHNOLOGIES           0.028308

# %%
q="""select Major,Major_category,Sharewomen from recent_grads
where Sharewomen>(select avg(Sharewomen)from recent_grads)
"""
pd.read_sql_query(q,conn)
# Out:
#                                  Major            Major_category  ShareWomen
# 0                    ACTUARIAL SCIENCE                  Business    0.535714
# 1                     COMPUTER SCIENCE   Computers & Mathematics    0.578766
# 2            ENVIRONMENTAL ENGINEERING               Engineering    0.558548
# 3                              NURSING                    Health    0.896019
# 4   INDUSTRIAL PRODUCTION TECHNOLOGIES               Engineering    0.750473
# ..                                 ...                       ...         ...
# 86                             ZOOLOGY    Biology & Life Science    0.637293
# 87              EDUCATIONAL PSYCHOLOGY  Psychology & Social Work    0.817099
# 88                 CLINICAL PSYCHOLOGY  Psychology & Social Work    0.799859
# 89               COUNSELING PSYCHOLOGY  Psychology & Social Work    0.798746
# 90                     LIBRARY SCIENCE                 Education    0.877960
#
# [91 rows x 3 columns]

# %%
q="""select count(Major) from recent_grads  """
pd.read_sql_query(q,conn)
# Out:
#    count(Major)
# 0           173

# %%
q="""select count(Major) from recent_grads where Sharewomen>(select avg(Sharewomen) from recent_grads)"""
pd.read_sql_query(q,conn)
# Out:
#    count(Major)
# 0            91

# %%
q="""select count(Major) as fields,(select count(Major) from recent_grads where Sharewomen>(select avg(Sharewomen) from recent_grads)) as 'fieldswheresharewomen>91' from recent_grads """
pd.read_sql_query(q,conn)
# Out:
#    fields  fieldswheresharewomen>91
# 0     173                        91

# %%
q="""select count(Major),(select count(Major) from recent_grads where Sharewomen>(select avg(Sharewomen) from recent_grads))from recent_grads """
pd.read_sql_query(q,conn)
# Out:
#    count(Major)  \
# 0           173
#
#    (select count(Major) from recent_grads where Sharewomen>(select avg(Sharewomen) from recent_grads))
# 0                                                 91

# %%
q="""select count(Major),(select count(Major) from recent_grads ) from recent_grads where Sharewomen>(select avg(Sharewomen) from recent_grads)"""
pd.read_sql_query(q,conn)
# Out:
#    count(Major)  (select count(Major) from recent_grads )
# 0            91                                       173

# %%
q="""select cast(count(Major )as float)/
(select count(Major) from recent_grads )*100 as percentfieldgreaterthanavgsharewomen from recent_grads where Sharewomen>(select avg(Sharewomen) from recent_grads)"""
pd.read_sql_query(q,conn)
# Out:
#    percentfieldgreaterthanavgsharewomen
# 0                             52.601156

# %%
q="""select Major_Category,MEN + Women from recent_grads"""
pd.read_sql_query(q,conn)
# Out:
#                Major_category  MEN + Women
# 0                 Engineering         2339
# 1                 Engineering          756
# 2                 Engineering          856
# 3                 Engineering         1258
# 4                 Engineering        32260
# ..                        ...          ...
# 168    Biology & Life Science         8409
# 169  Psychology & Social Work         2854
# 170  Psychology & Social Work         2838
# 171  Psychology & Social Work         4626
# 172                 Education         1098
#
# [173 rows x 2 columns]

# %%
q="""select Major_category,cast( sum(women)as float)/ sum(men +women)*100 as womenspercentage from recent_grads 
where Major_category="Engineering" """


pd.read_sql_query(q,conn)
# Out:
#   Major_category  womenspercentage
# 0    Engineering         22.759232

# %%
q="""select Major_category,cast( sum(women)as float)/ sum(men +women)*100 as womenspercentage from recent_grads 
group by 1 """
pd.read_sql_query(q,conn)
# Out:
#                          Major_category  womenspercentage
# 0       Agriculture & Natural Resources         55.800593
# 1                                  Arts         61.812541
# 2                Biology & Life Science         57.472103
# 3                              Business         38.417385
# 4           Communications & Journalism         72.814700
# 5               Computers & Mathematics         51.217457
# 6                             Education         70.400726
# 7                           Engineering         22.759232
# 8                                Health         76.729718
# 9             Humanities & Liberal Arts         68.612448
# 10  Industrial Arts & Consumer Services         51.239094
# 11                    Interdisciplinary         49.539715
# 12                  Law & Public Policy         34.319008
# 13                    Physical Sciences         56.992382
# 14             Psychology & Social Work         68.150691
# ...

# %%
q="""select Major_category from recent_grads
    group by 1
        order by sum(men+women) DESC limit 3"""
pd.read_sql_query(q,conn)
# Out:
#            Major_category
# 0  Biology & Life Science
# 1          Social Science
# 2               Education

# %%
q="""select Major,Major_category from recent_grads where Major_category in (select Major_category from recent_grads
    group by 1
        order by sum(men+women) DESC limit 3)"""
pd.read_sql_query(q,conn)
# Out:
#                                           Major          Major_category
# 0                                     ECONOMICS          Social Science
# 1                                  PHARMACOLOGY  Biology & Life Science
# 2           COGNITIVE SCIENCE AND BIOPSYCHOLOGY  Biology & Life Science
# 3                     SCHOOL STUDENT COUNSELING               Education
# 4                       INTERNATIONAL RELATIONS          Social Science
# 5                             MOLECULAR BIOLOGY  Biology & Life Science
# 6                                      GENETICS  Biology & Life Science
# 7                 MISCELLANEOUS SOCIAL SCIENCES          Social Science
# 8              POLITICAL SCIENCE AND GOVERNMENT          Social Science
# 9                                     GEOGRAPHY          Social Science
# 10                                 MICROBIOLOGY  Biology & Life Science
# 11                         BIOCHEMICAL SCIENCES  Biology & Life Science
# ...
